# %% [markdown]
# # Cardiovascular Disease Prediction using Machine Learning

# %% [markdown]
# ## Week 1: Problem Definition and Dataset Exploration

# %% [markdown]
# ## Problem Statement
#  The objective of this project is to predict whether a patient has cardiovascular disease using machine learning techniques based on various health-related attributes such as age, gender, blood pressure, cholesterol level, glucose level, smoking habits, alcohol consumption, and physical activity.

# %% [markdown]
# ## Imported Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv("cardio_train (1).csv",sep=";")

# %% [markdown]
# ## Dataset Exploration

# %%
df.head()  #shows the first 5 rows of datasets
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
df.shape  #no. of rows and columns
# Out:
# (70000, 13)

# %%
df.info()    
#using .info(memory_usage='deep') gives the same output because all columns are numeric
# so there are no noticable difference
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %%
df.sample(5)  # Random displays 5 rows
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 2227    3145  21100       2     169    70.0    140     90            2     2
# 61830  88282  22102       1     155    57.0    120     80            1     1
# 66473  94898  17478       1     178    80.0    150     90            1     1
# 54572  77853  21640       1     154    88.0    130     80            3     1
# 4462    6320  21929       1     160    80.0    120     80            2     1
#
#        smoke  alco  active  cardio
# 2227       1     0       1       1
# 61830      0     0       1       1
# 66473      0     0       0       1
# 54572      0     0       1       1
# 4462       0     0       1       0

# %%
df.columns.tolist()   #list of dataset columns
# Out:
# ['id',
#  'age',
#  'gender',
#  'height',
#  'weight',
#  'ap_hi',
#  'ap_lo',
#  'cholesterol',
#  'gluc',
#  'smoke',
#  'alco',
#  'active',
#  'cardio']

# %%
df.select_dtypes(include = 'number').columns.tolist()
# Out:
# ['id',
#  'age',
#  'gender',
#  'height',
#  'weight',
#  'ap_hi',
#  'ap_lo',
#  'cholesterol',
#  'gluc',
#  'smoke',
#  'alco',
#  'active',
#  'cardio']

# %%
print(f"Rows : {df.shape[0]}")
print(f"Columns : {df.shape[1]}")  #dataset dimensions
# Out:
# Rows : 70000
# Columns : 13

# %%
df.describe()  #mean,min,max,standard deviation,etc.(statistical summary) (for numerical columns)
# .describe(include = "all"): gives statistics for all columns including categorical columns.
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %%
df.isnull().sum()    #checking missing values
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
df.duplicated().sum()   #checking duplicate rows
# Out:
# np.int64(0)

# %%
df.columns   #list all column names
# Out:
# Index(['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
df.nunique()   #Unique values in each columns
# Out:
# id             70000
# age             8076
# gender             2
# height           109
# weight           287
# ap_hi            153
# ap_lo            157
# cholesterol        3
# gluc               3
# smoke              2
# alco               2
# active             2
# cardio             2
# dtype: int64

# %%
df["cardio"].value_counts()  #how many have disease(1) or not(0)
# Out:
# cardio
# 0    35021
# 1    34979
# Name: count, dtype: int64

# %%
df["cardio"].value_counts(normalize=True)*100  #percentage of each class
# Out:
# cardio
# 0    50.03
# 1    49.97
# Name: proportion, dtype: float64

# %%
df.tail()  #Last five rows
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# 69995      1     0       1       0
# 69996      0     0       1       1
# 69997      0     1       0       1
# 69998      0     0       0       1
# 69999      0     0       1       0

# %% [markdown]
# ## Graphical Representation of Dataset

# %% [markdown]
# ### Graph 1: Distribution of Target Variable(Cardiovascular Disease)
# The graph shows the distribution of patients with and without cardiovascular disease.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
sns.countplot(x='cardio', data=df, color='#14B8A6')
plt.title("Distribution of Cardiovascular Disease")
plt.xlabel("Cardiovascular Disease (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Graph 2: Age Distribution
# The histogram shows the distribution of patients' ages in the dataset.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
sns.histplot(df['age'], bins=15, kde=False, color='#14B8A6')
plt.title("Age Distribution")
plt.xlabel("Age (Days)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Graph 3: Gender Distribution
# This graph shows the number of male and female patients in the dataset.

# %%
import matplotlib.pyplot as plt

gender_counts = df['gender'].value_counts()

colors = ['#FF6B6B', '#1E3A8A']  # Coral, Navy

plt.figure(figsize=(6,6))
plt.pie(
    gender_counts,
    labels=['Women', 'Men'],
    autopct='%1.1f%%',
    startangle=90,
    colors=colors
)
plt.title("Gender Distribution")
plt.show()

# %% [markdown]
# ### Graph 4: Cholesterol Level Distribution
# The graph displays the frequency of each cholesterol level.

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='cholesterol', data=df)
plt.title("Cholesterol Level Distribution")
plt.xlabel("Cholesterol Level")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Graph 5: Correlation Heatmap
# - The heatmap represents the correlation between all numerical variables.
# - Darker colors indicate stronger positive or negative relationships.
# - Features with higher correlation to the target variable can be useful for prediction.

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Summary

# %% [markdown]
# -  Successfully imported all the required Python libraries.
# - Loaded the Cardiovascular Disease dataset.
# - Explored the dataset using Pandas functions.
# -  Verified that the dataset contains **70,000 records** and **13 features**.
# - Checked for missing values and found none.
# - Checked for duplicate values and found none.
# - Identified the dataset columns and their data types.
# - Visualized important features using graphs.
# - Generated a correlation heatmap to understand relationships between variables.
# - The dataset is ready for preprocessing and further analysis.
